# %%
import numpy as np
import pandas as pd

# %%
path =pd.read_csv("C:\\Users\\Nwambuonwo\\Documents\\covid.csv")

# %%
path
# Out:
#             location       iso_code        date   total_vaccinations  \
# 0      #country+name  #country+code       #date  #total+vaccinations
# 1        Afghanistan            AFG  2021-02-22                    0
# 2        Afghanistan            AFG  2021-02-23                  NaN
# 3        Afghanistan            AFG  2021-02-24                  NaN
# 4        Afghanistan            AFG  2021-02-25                  NaN
# ...              ...            ...         ...                  ...
# 48085       Zimbabwe            ZWE  2021-09-11              4708905
# 48086       Zimbabwe            ZWE  2021-09-12                  NaN
# 48087       Zimbabwe            ZWE  2021-09-13              4752356
# 48088       Zimbabwe            ZWE  2021-09-14              4800761
# 48089       Zimbabwe            ZWE  2021-09-15              4855816
#
#        people_vaccinated  people_fully_vaccinated  total_boosters  \
# 0                    NaN                      NaN             NaN
# ...

# %%
path['location'].sort_values()
# Out:
# 0        #country+name
# 122        Afghanistan
# 123        Afghanistan
# 124        Afghanistan
# 125        Afghanistan
#              ...
# 47953         Zimbabwe
# 47954         Zimbabwe
# 47955         Zimbabwe
# 47930         Zimbabwe
# 48089         Zimbabwe
# Name: location, Length: 48090, dtype: object

# %%
boolean[]=
for length in path.location:
    if length >=75:
    boolean.append(True)
    else:
        boolean.append(False)
# Out:
#   File "<ipython-input-33-07cea4ff00b0>", line 1
#     boolean[]=
#             ^
# SyntaxError: invalid syntax

# %%
        path[boolean]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-218013d4ca1b> in <module>
# ----> 1 path[boolean]
#
# NameError: name 'boolean' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-b3b5d49c8ff0> in <module>
# ----> 1 path.daily_vaccinations_raw.plot()
#       2 path
#
# ~\.conda\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     765
#     766     def __call__(self, *args, **kwargs):
# --> 767         plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     768
#     769         x, y, kind, kwargs = self._get_call_args(
#
# ~\.conda\lib\site-packages\pandas\plotting\_core.py in _get_plot_backend(backend)
#    1662         # we need to attempt an import here to raise an ImportError if needed.
#    1663         try:
# -> 1664             import pandas.plotting._matplotlib as module
#    1665         except ImportError:
#    1666             raise ImportError(
#
# ~\.conda\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in <module>
# ...
